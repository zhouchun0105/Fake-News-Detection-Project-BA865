# %% [markdown]
# <a href="https://colab.research.google.com/github/zhouchun0105/Fake-News-Detection-Project-BA865/blob/main/BA865_Fake_News_Classification_Project_tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
# imports 
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud

# %%
# Mounting Google Drive locally
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Setup and Data Cleaning

# %%
# Import data 
df_fakenews_true = pd.read_csv("gdrive/Shared drives/BA865 Group Project/News _dataset/True.csv")
df_fakenews_fake = pd.read_csv("gdrive/Shared drives/BA865 Group Project/News _dataset/Fake.csv")

# %%
df_fakenews_true.head()
# Out:
#                                                title  ...                date
# 0  As U.S. budget fight looms, Republicans flip t...  ...  December 31, 2017
# 1  U.S. military to accept transgender recruits o...  ...  December 29, 2017
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...  December 31, 2017
# 3  FBI Russia probe helped by Australian diplomat...  ...  December 30, 2017
# 4  Trump wants Postal Service to charge 'much mor...  ...  December 29, 2017
#
# [5 rows x 4 columns]

# %%
df_fakenews_fake.head()
# Out:
#                                                title  ...               date
# 0   Donald Trump Sends Out Embarrassing New Year’...  ...  December 31, 2017
# 1   Drunk Bragging Trump Staffer Started Russian ...  ...  December 31, 2017
# 2   Sheriff David Clarke Becomes An Internet Joke...  ...  December 30, 2017
# 3   Trump Is So Obsessed He Even Has Obama’s Name...  ...  December 29, 2017
# 4   Pope Francis Just Called Out Donald Trump Dur...  ...  December 25, 2017
#
# [5 rows x 4 columns]

# %%
df_fakenews_true.describe()
# Out:
#                                                     title  ...                date
# count                                               21417  ...               21417
# unique                                              20826  ...                 716
# top     Factbox: Trump fills top jobs for his administ...  ...  December 20, 2017
# freq                                                   14  ...                 182
#
# [4 rows x 4 columns]

# %%
df_fakenews_fake.describe()
# Out:
#                                                     title  ...          date
# count                                               23481  ...         23481
# unique                                              17903  ...          1681
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...  ...  May 10, 2017
# freq                                                    6  ...            46
#
# [4 rows x 4 columns]

# %%
df_fakenews_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
df_fakenews_fake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
print(df_fakenews_true.shape)
print(df_fakenews_fake.shape)
# Out:
# (21417, 4)
# (23481, 4)

# %%
# checking for any null values
df_fakenews_true.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
# checking for any null values
df_fakenews_fake.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %% [markdown]
# # Data Pre-Processing

# %%
# creating new colum 'Real/Fake', labeling the two datasets in order to merge and know which observation is real and which one is false
df_fakenews_true['real/fake'] = '1'
df_fakenews_fake['real/fake'] = '0'

# %%
# merging the two datasets
frames = [df_fakenews_true, df_fakenews_fake]
news_data = pd.concat(frames)
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      44898 non-null  object
#  1   text       44898 non-null  object
#  2   subject    44898 non-null  object
#  3   date       44898 non-null  object
#  4   real/fake  44898 non-null  object
# dtypes: object(5)
# memory usage: 2.1+ MB

# %%
news_data.head()
# Out:
#                                                title  ... real/fake
# 0  As U.S. budget fight looms, Republicans flip t...  ...         1
# 1  U.S. military to accept transgender recruits o...  ...         1
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...         1
# 3  FBI Russia probe helped by Australian diplomat...  ...         1
# 4  Trump wants Postal Service to charge 'much mor...  ...         1
#
# [5 rows x 5 columns]

# %%
# date column Split to see if there are seasonal trends
# splitting the Year, the Month and Day Data
date_split1 = news_data['date'].str.split(',', expand=True)
news_data['Year']=date_split1[1]

date_split2 = news_data['date'].str.split(' ', expand=True)
news_data['Month']=date_split2[0]
news_data['Day']=date_split2[1]
news_data['Day'] = news_data['Day'].replace(',','', regex=True)

# %%
# dropping date column 
news_data = news_data.drop('date', axis=1)
news_data.head()
# Out:
#                                                title  ... Day
# 0  As U.S. budget fight looms, Republicans flip t...  ...  31
# 1  U.S. military to accept transgender recruits o...  ...  29
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...  31
# 3  FBI Russia probe helped by Australian diplomat...  ...  30
# 4  Trump wants Postal Service to charge 'much mor...  ...  29
#
# [5 rows x 7 columns]

# %%
# one-hot encoding for subject column

# %%
# title and text can be two seperate variables

# %% [markdown]
# # EDA

# %%
# word cloud for the text real true News
text_true = pd.Series(df_fakenews_true['text'].tolist()).astype(str)

cloud = WordCloud(width=1300, height=950).generate(" ".join(text_true.astype(str)))
plt.figure(figsize=(15, 10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1299.5, 949.5, -0.5)

# %%
# word cloud for the text false fake News
text_false = pd.Series(df_fakenews_true['text'].tolist()).astype(str)

cloud = WordCloud(width=1300, height=950).generate(" ".join(text_false.astype(str)))
plt.figure(figsize=(15, 10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1299.5, 949.5, -0.5)

# %% [markdown]
# # Feature Engineering/Natural Language Processing
#
#
# *   TfiDf Vectorizer
# *   SpaCy
# *   Work Tokenizer

# %%
import re
import spacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer,TfidfVectorizer  
import nltk

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      44898 non-null  object
#  1   text       44898 non-null  object
#  2   subject    44898 non-null  object
#  3   real/fake  44898 non-null  object
#  4   Year       44853 non-null  object
#  5   Month      44898 non-null  object
#  6   Day        44854 non-null  object
# dtypes: object(7)
# memory usage: 2.7+ MB

# %%
news_data.head(5)
# Out:
#                                                title  ... Day
# 0  As U.S. budget fight looms, Republicans flip t...  ...  31
# 1  U.S. military to accept transgender recruits o...  ...  29
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...  31
# 3  FBI Russia probe helped by Australian diplomat...  ...  30
# 4  Trump wants Postal Service to charge 'much mor...  ...  29
#
# [5 rows x 7 columns]

# %%
news_data['title_lower'] = news_data.title.str.lower()

# %%
import string

# %%
def remove_punct(text):
  text = ''.join([p for p in text if p not in set(string.punctuation)])
  return text

# %%
news_data['title2'] = news_data.title_lower.apply(remove_punct)

# %%
news_data['tokens'] = news_data.title2.str.split()

# %%
news_data.head(3)
# Out:
#                                                title  ...                                             tokens
# 0  As U.S. budget fight looms, Republicans flip t...  ...  [as, us, budget, fight, looms, republicans, fl...
# 1  U.S. military to accept transgender recruits o...  ...  [us, military, to, accept, transgender, recrui...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...  [senior, us, republican, senator, let, mr, mue...
#
# [3 rows x 10 columns]

# %% [markdown]
# Stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# get the stopwords
from nltk.corpus import stopwords
STOPWORDS = list(stopwords.words('english'))

# %%
type(STOPWORDS)
# Out:
# list

# %%
len(STOPWORDS)
# Out:
# 179

# %%
cv= CountVectorizer(stop_words= STOPWORDS)
cv.fit(news_data.title2)
# Out:
# CountVectorizer(stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours',
#                             'ourselves', 'you', "you're", "you've", "you'll",
#                             "you'd", 'your', 'yours', 'yourself', 'yourselves',
#                             'he', 'him', 'his', 'himself', 'she', "she's",
#                             'her', 'hers', 'herself', 'it', "it's", 'its',
#                             'itself', ...])

# %%
cv.vocabulary_
# Out:
# {'us': 22062,
#  'budget': 3437,
#  'fight': 8413,
#  'looms': 12592,
#  'republicans': 17413,
#  'flip': 8643,
#  'fiscal': 8532,
#  'script': 18459,
#  'military': 13414,
#  'accept': 839,
#  'transgender': 21248,
#  'recruits': 17028,
#  'monday': 13656,
#  'pentagon': 15359,
#  'senior': 18631,
#  'republican': 17411,
#  'senator': 18622,
#  'let': 12301,
#  'mr': 13821,
#  'mueller': 13836,
#  'job': 11555,
#  'fbi': 8271,
#  'russia': 18037,
#  'probe': 16184,
#  'helped': 10174,
#  'australian': 2101,
#  'diplomat': 6348,
#  'tipoff': 21014,
#  'nyt': 14459,
#  'trump': 21402,
#  'wants': 22543,
#  'postal': 15872,
#  'service': 18684,
#  'charge': 4067,
#  'much': 13831,
#  'amazon': 1377,
#  'shipments': 18871,
#  'white': 22801,
#  'house': 10478,
#  'congress': 4906,
#  'prepare': 16047,
#  'talks': 20537,
#  'spending': 19608,
#  'immigration': 10762,
#  'says': 18280,
#  'fair': 8125,
#  'timeline': 20994,
#  'unclear': 21716,
#  'factbox': 8098,
#  'twitter': 21590,
#  'dec': 5761,
#  '29': 348,
#  'approval': 1778,
#  'rating': 16843,
#  '28': 343,
#  'global': 9360,
#  'warming': 22562,
#  'alabama': 1199,
#  'official': 14603,
#  'certify': 3991,
#  'senatorelect': 18623,
#  'jones': 11591,
#  'today': 21041,
#  'despite': 6158,
#  'challenge': 4022,
#  'cnn': 4485,
#  'certified': 3989,
#  'senate': 18620,
#  'winner': 22900,
#  'moore': 13709,
#  'new': 14151,
#  'york': 23184,
#  'governor': 9487,
#  'questions': 16647,
#  'constitutionality': 4962,
#  'federal': 8310,
#  'tax': 20616,
#  'overhaul': 14928,
#  'vanity': 22182,
#  'hillary': 10269,
#  'clinton': 4426,
#  '27': 334,
#  'iraq': 11304,
#  'syria': 20468,
#  'man': 12868,
#  'delivered': 5958,
#  'manure': 12934,
#  'mnuchin': 13582,
#  'protest': 16399,
#  'law': 12134,
#  'virginia': 22372,
#  'officials': 14605,
#  'postpone': 15899,
#  'lottery': 12629,
#  'drawing': 6841,
#  'decide': 5787,
#  'tied': 20967,
#  'statehouse': 19847,
#  'election': 7187,
#  'lawmakers': 12144,
#  'question': 16642,
#  'businessman': 3554,
#  '2016': 253,
#  'tower': 21169,
#  'meeting': 13200,
#  'sources': 19516,
#  '26': 329,
#  'cut': 5550,
#  'bill': 2761,
#  'appeals': 1736,
#  'court': 5236,
#  'rejects': 17212,
#  'voter': 22440,
#  'fraud': 8891,
#  'panel': 15068,
#  'treasury': 21298,
#  'secretary': 18522,
#  'sent': 18639,
#  'giftwrapped': 9296,
#  'box': 3157,
#  'horse': 10445,
#  'reports': 17387,
#  'judge': 11629,
#  'partially': 15162,
#  'lifts': 12394,
#  'trumps': 21456,
#  'latest': 12089,
#  'refugee': 17122,
#  'restrictions': 17534,
#  'exclusive': 7748,
#  'memo': 13245,
#  'weakens': 22656,
#  'guidelines': 9719,
#  'protecting': 16391,
#  'immigrant': 10759,
#  'children': 4187,
#  'travel': 21280,
#  'ban': 2341,
#  'apply': 1755,
#  'people': 15363,
#  'strong': 20097,
#  'ties': 20970,
#  'second': 18515,
#  'bid': 2731,
#  'stop': 19990,
#  'failed': 8118,
#  'vote': 22436,
#  'oust': 14849,
#  'president': 16076,
#  'shakes': 18760,
#  'perus': 15432,
#  'politics': 15773,
#  'signs': 19040,
#  'government': 9483,
#  'bills': 2775,
#  'companies': 4723,
#  'year': 23141,
#  'reporting': 17386,
#  'sec': 18509,
#  '22': 288,
#  'missile': 13530,
#  'defense': 5874,
#  'mexico': 13328,
#  'review': 17640,
#  'need': 14077,
#  'changes': 4046,
#  'reformdocument': 17108,
#  'leader': 12171,
#  'mcconnell': 13124,
#  'sees': 18558,
#  'collegial': 4591,
#  '2018': 257,
#  'democrat': 5987,
#  'happier': 9936,
#  'tweets': 21574,
#  'victory': 22288,
#  'asks': 1925,
#  'extop': 8006,
#  'aide': 1141,
#  'bannon': 2368,
#  'testify': 20796,
#  'bloomberg': 2946,
#  'callista': 3652,
#  'gingrich': 9313,
#  'becomes': 2558,
#  'envoy': 7466,
#  'pope': 15811,
#  'differences': 6301,
#  'mount': 13784,
#  'aim': 1151,
#  'ride': 17707,
#  'economy': 7088,
#  'warning': 22571,
#  'voters': 22443,
#  'key': 11771,
#  'district': 6586,
#  'state': 19842,
#  'department': 6050,
#  'tells': 20710,
#  'agencies': 1095,
#  'downsize': 6800,
#  'operations': 14732,
#  'votes': 22444,
#  'avert': 2143,
#  'shutdown': 18986,
#  'sends': 18628,
#  'stopgap': 19992,
#  'bigticket': 2747,
#  'items': 11397,
#  'center': 3965,
#  'tosses': 21130,
#  'suit': 20240,
#  'foreign': 8761,
#  'payments': 15275,
#  'shelves': 18837,
#  'disaster': 6397,
#  'aid': 1140,
#  'next': 14173,
#  'month': 13690,
#  '21': 279,
#  'cuts': 5554,
#  'home': 10371,
#  'sales': 18153,
#  'widens': 22841,
#  'ethics': 7593,
#  'include': 10879,
#  'farenthold': 8198,
#  'campaign': 3679,
#  'work': 23000,
#  'jan': 11447,
#  'approves': 1782,
#  '81': 658,
#  'billion': 2766,
#  'democrats': 5990,
#  'rally': 16759,
#  'protect': 16389,
#  'special': 19574,
#  'counsel': 5200,
#  'blocks': 2928,
#  'administration': 973,
#  'birth': 2803,
#  'control': 5034,
#  'rules': 18002,
#  'senators': 18624,
#  'seek': 18548,
#  'expansion': 7878,
#  'airport': 1176,
#  'facial': 8090,
#  'scans': 18311,
#  'launches': 12115,
#  'effort': 7134,
#  'reduce': 17057,
#  'reliance': 17244,
#  'imports': 10820,
#  'critical': 5394,
#  'minerals': 13460,
#  'shortterm': 18926,
#  'funding': 9047,
#  'advance': 1009,
#  'spy': 19717,
#  'chiefs': 4175,
#  'pressure': 16089,
#  'renew': 17315,
#  'expiring': 7915,
#  'surveillance': 20351,
#  'urges': 22053,
#  'pass': 15190,
#  'gives': 9329,
#  'final': 8447,
#  'delivering': 5960,
#  'plan': 15631,
#  'roils': 17863,
#  'popular': 15819,
#  'bet': 2693,
#  'bond': 3050,
#  'market': 12980,
#  'temporary': 20724,
#  'extension': 7996,
#  'internet': 11184,
#  'spying': 19718,
#  'program': 16261,
#  'commutes': 4720,
#  'sentence': 18640,
#  'kosher': 11918,
#  'meatpacker': 13166,
#  'responds': 17507,
#  'illegal': 10708,
#  'indonesian': 10950,
#  'immigrants': 10760,
#  'franken': 8881,
#  'leave': 12204,
#  'january': 11453,
#  'temporarily': 20723,
#  'top': 21097,
#  'firing': 8521,
#  'could': 5193,
#  'provoke': 16438,
#  'constitutional': 4961,
#  'crisis': 5389,
#  'may': 13100,
#  'face': 8079,
#  'lawsuits': 12152,
#  'long': 12567,
#  'odds': 14568,
#  'political': 15763,
#  'payoffs': 15278,
#  'dreamers': 6854,
#  'hinges': 10286,
#  'bipartisan': 2795,
#  'pact': 15008,
#  'hurt': 10594,
#  'puerto': 16498,
#  'rico': 17702,
#  'use': 22076,
#  'attack': 2039,
#  'midterms': 13385,
#  'ruling': 18004,
#  'legislatures': 12255,
#  'majority': 12815,
#  'chosen': 4240,
#  'lot': 12626,
#  'alaska': 1211,
#  'arctic': 1811,
#  'drilling': 6870,
#  'begun': 2584,
#  'opponents': 14746,
#  'vow': 22449,
#  'cornyn': 5135,
#  'trying': 21481,
#  'get': 9267,
#  'big': 2737,
#  'corn': 5128,
#  'behind': 2598,
#  'biofuels': 2786,
#  'reform': 17106,
#  'georgia': 9246,
#  'battle': 2499,
#  'staceys': 19761,
#  'tests': 20800,
#  'future': 9080,
#  'wins': 22905,
#  'one': 14675,
#  'legislative': 12251,
#  'recount': 17011,
#  'deputy': 6099,
#  'director': 6362,
#  'sit': 19117,
#  'closed': 4450,
#  'interview': 11208,
#  'panels': 15071,
#  'expects': 7888,
#  'waive': 22499,
#  'triggered': 21347,
#  '20': 233,
#  'whats': 22763,
#  'fully': 9027,
#  'digested': 6310,
#  'fix': 8561,
#  'childrens': 4188,
#  'health': 10087,
#  'passthrough': 15201,
#  'rule': 17997,
#  'wealthy': 22666,
#  'workers': 23004,
#  'critics': 5403,
#  'wont': 22985,
#  'make': 12820,
#  'housing': 10482,
#  'affordable': 1064,
#  'analysts': 1442,
#  'banks': 2363,
#  'healthcare': 10088,
#  'firms': 8524,
#  'among': 1423,
#  'winners': 22901,
#  'supreme': 20318,
#  'appointee': 1759,
#  'gorsuch': 9466,
#  'plots': 15687,
#  'rightward': 17738,
#  'course': 5234,
#  'letter': 12305,
#  'aides': 1143,
#  'hope': 10423,
#  'win': 22888,
#  'taxes': 20622,
#  'stem': 19901,
#  'slide': 19235,
#  'poll': 15776,
#  'numbers': 14429,
#  'faces': 8088,
#  'tricky': 21343,
#  'path': 15220,
#  'avoid': 2153,
#  'parliamentarian': 15146,
#  'provisions': 16434,
#  'sanders': 18198,
#  'snubs': 19387,
#  'pick': 15522,
#  'run': 18015,
#  'exim': 7825,
#  'oks': 14639,
#  'nominees': 14277,
#  'likely': 12408,
#  'instant': 11103,
#  'view': 22319,
#  'biggest': 2739,
#  '30': 359,
#  'years': 23147,
#  'begins': 2582,
#  'debate': 5740,
#  'members': 13241,
#  'liable': 12335,
#  'harassment': 9950,
#  'payouts': 15280,
#  'green': 9584,
#  'groups': 9667,
#  'sue': 20218,
#  'delay': 5930,
#  'methane': 13318,
#  'democratic': 5988,
#  'leaders': 12174,
#  'urging': 22054,
#  'reporter': 17383,
#  'pence': 15339,
#  'preside': 16074,
#  'office': 14599,
#  'confirms': 4873,
#  'tuesday': 21501,
#  'evening': 7654,
#  'appear': 1737,
#  'certain': 3985,
#  'legislation': 12250,
#  'orders': 14791,
#  'give': 9325,
#  'teens': 20680,
#  'abortion': 793,
#  'access': 845,
#  'would': 23037,
#  'increase': 10898,
#  'request': 17421,
#  'chair': 4012,
#  'introduces': 11225,
#  'nominates': 14272,
#  'liberty': 12354,
#  'university': 21877,
#  'professor': 16245,
#  'justice': 11672,
#  'post': 15868,
#  '18': 170,
#  'congressional': 4907,
#  'races': 16694,
#  'train': 21216,
#  'accident': 849,
#  'cabinet': 3606,
#  'visit': 22388,
#  'assess': 1967,
#  'recovery': 17018,
#  'dreamer': 6853,
#  'agenda': 1098,
#  'warren': 22581,
#  'hits': 10320,
#  'politicize': 15767,
#  'consumer': 4976,
#  'agency': 1096,
#  'strategy': 20040,
#  'document': 6661,
#  'meddles': 13175,
#  'domestic': 6698,
#  'affairs': 1050,
#  'worldwide': 23017,
#  'collins': 4595,
#  'seeks': 18552,
#  'audit': 2082,
#  'epa': 7469,
#  'trip': 21360,
#  'morocco': 13732,
#  'lee': 12221,
#  'choice': 4218,
#  'deal': 5718,
#  'north': 14342,
#  'korea': 11912,
#  'arms': 1854,
#  'judicial': 11636,
#  'nominee': 14276,
#  'withdraws': 22945,
#  'consideration': 4943,
#  'calls': 3654,
#  'infrastructure': 11013,
#  'derailment': 6104,
#  'slashes': 19203,
#  'corporate': 5141,
#  'rate': 16837,
#  'voting': 22445,
#  'week': 22697,
#  'defends': 5873,
#  'great': 9571,
#  'christmas': 4255,
#  'gifts': 9295,
#  'middle': 13363,
#  'class': 4353,
#  'afternoon': 1085,
#  'optimistic': 14769,
#  'taxpayers': 20629,
#  'rush': 18031,
#  'claim': 4327,
#  'deductions': 5829,
#  'threat': 20900,
#  'confident': 4864,
#  'become': 2557,
#  'john': 11570,
#  'mccain': 13118,
#  'leaves': 12206,
#  'washington': 22602,
#  'expected': 7886,
#  'considering': 4945,
#  'allies': 1294,
#  'say': 18277,
#  'unlawfully': 21884,
#  'obtained': 14546,
#  'thousands': 20896,
#  'emails': 7245,
#  'joining': 11577,
#  'resignation': 17470,
#  'bans': 2371,
#  'selected': 18577,
#  'words': 22998,
#  'paper': 15094,
#  'congressman': 4909,
#  'relection': 17239,
#  'amid': 1413,
#  'misconduct': 13501,
#  'security': 18540,
#  'speech': 19591,
#  'china': 4200,
#  'competitor': 4745,
#  'december': 5777,
#  '15': 128,
#  'quantico': 16619,
#  'retains': 17564,
#  'electric': 7197,
#  'vehicle': 22204,
#  'credit': 5346,
#  'attorney': 2062,
#  'general': 9211,
#  'sessions': 18693,
#  'lukewarm': 12686,
#  'praise': 15963,
#  'force': 8745,
#  'fcc': 8275,
#  'net': 14132,
#  'neutrality': 14142,
#  'repeal': 17355,
#  'lawmaker': 12143,
#  'probed': 16185,
#  'sex': 18723,
#  'denies': 6024,
#  'charges': 4069,
#  'join': 11575,
#  'push': 16566,
#  'lift': 12391,
#  'secrecy': 18519,
#  'around': 1861,
#  'brief': 3304,
#  'hill': 10268,
#  'staff': 19766,
#  'saudi': 18251,
#  'reactors': 16881,
#  'enrichment': 7419,
#  'worry': 23022,
#  'arrest': 1866,
#  'former': 8801,
#  'manager': 12875,
#  'manafort': 12869,
#  'corker': 5127,
#  'support': 20301,
#  'rubio': 17980,
#  'signals': 19033,
#  'child': 4179,
#  'tweaks': 21568,
#  'negotiators': 14098,
#  'raising': 16751,
#  'refundable': 17127,
#  'portion': 15836,
#  'congresswoman': 4914,
#  'finalized': 8450,
#  'compromise': 4780,
#  'chief': 4174,
#  'writer': 23075,
#  'back': 2218,
#  'cnbc': 4484,
#  'citing': 4309,
#  'cruz': 5469,
#  'cap': 3735,
#  'renewable': 17316,
#  'fuel': 9001,
#  'credits': 5350,
#  '10': 6,
#  'cents': 3976,
#  'issues': 11386,
#  'visa': 22379,
#  'waivers': 22501,
#  'concede': 4794,
#  'race': 16685,
#  'fresh': 8940,
#  'way': 22647,
#  'reach': 16872,
#  'millennials': 13427,
#  'nears': 14067,
#  'waver': 22641,
#  '14': 110,
#  'stock': 19958,
#  'regulations': 17168,
#  'committee': 4697,
#  'head': 10068,
#  'data': 5670,
#  'firm': 8522,
#  'governors': 9491,
#  'meet': 13199,
#  'nafta': 13950,
#  'concerns': 4806,
#  'speaker': 19570,
#  'ryan': 18079,
#  'mulls': 13854,
#  'retirement': 17582,
#  'elections': 7190,
#  'politico': 15771,
#  'representative': 17392,
#  'reelection': 17071,
#  'rival': 17784,
#  'move': 13797,
#  'fund': 9038,
#  'managers': 12876,
#  'stocks': 19962,
#  'benefiting': 2646,
#  'gains': 9114,
#  'keep': 11735,
#  'eye': 8046,
#  'told': 21058,
#  'report': 17380,
#  'rumors': 18012,
#  'true': 21400,
#  'undecided': 21735,
#  'preserve': 16070,
#  'energy': 7372,
#  'allow': 1305,
#  'property': 16344,
#  'income': 10886,
#  'chemical': 4140,
#  'safety': 18122,
#  'burr': 3531,
#  'tillis': 20985,
#  'oppose': 14750,
#  'dourson': 6777,
#  'delays': 5933,
#  'east': 7048,
#  'case': 3838,
#  'needed': 14078,
#  'kentucky': 11753,
#  'probable': 16181,
#  'suicide': 20236,
#  'sexual': 18734,
#  'accusations': 882,
#  'mulvaney': 13864,
#  'wednesday': 22693,
#  'donald': 6705,
#  'jr': 11616,
#  'leak': 12182,
#  'probes': 16187,
#  'press': 16084,
#  'expect': 7884,
#  'postcardsized': 15875,
#  'return': 17604,
#  'experts': 7910,
#  'forge': 8780,
#  'seen': 18556,
#  'thrills': 20920,
#  'point': 15729,
#  'fingers': 8478,
#  'eldest': 7181,
#  'son': 19470,
#  'testifies': 20795,
#  'minnesota': 13479,
#  'lieutenant': 12379,
#  'replace': 17370,
#  'unveiled': 21990,
#  '19': 186,
#  'dismisses': 6500,
#  'bias': 2722,
#  'treated': 21302,
#  'side': 19006,
#  'effects': 7127,
#  'cancer': 3710,
#  'therapy': 20848,
#  'dossier': 6753,
#  'leaked': 12183,
#  'bank': 2354,
#  'records': 17009,
#  'retaliation': 17572,
#  'two': 21592,
#  'nominations': 14275,
#  'rebuffed': 16941,
#  'prepares': 16049,
#  'open': 14713,
#  'doors': 6736,
#  'billiondollar': 2769,
#  'london': 12559,
#  'embassy': 7256,
#  'elaborate': 7171,
#  'hoax': 10329,
#  'websites': 22688,
#  'nfl': 14177,
#  'redskins': 17056,
#  'renamed': 17304,
#  'redhawks': 17042,
#  'upset': 22035,
#  'see': 18543,
#  'prospects': 16381,
#  'south': 19518,
#  'schumer': 18378,
#  'seated': 18504,
#  'still': 19945,
#  'stake': 19781,
#  'recounts': 17012,
#  'begin': 2579,
#  'percent': 15372,
#  'hatch': 10024,
#  'using': 22090,
#  'public': 16485,
#  'funds': 9053,
#  'settlements': 18703,
#  'agreement': 1122,
#  'principle': 16143,
#  'ap': 1705,
#  'omarosa': 14665,
#  'manigault': 12903,
#  'newman': 14158,
#  'resigns': 17474,
#  'analyst': 1441,
#  'seat': 18503,
#  'blow': 2952,
#  'hopeful': 10425,
#  'help': 10173,
#  'end': 7334,
#  'gillibrand': 9305,
#  'sexist': 18728,
#  'smear': 19303,
#  'loses': 12621,
#  'said': 18131,
#  'congratulates': 4904,
#  'tweet': 21569,
#  'prayer': 15976,
#  'guide': 9717,
#  'women': 22976,
#  'roy': 17964,
#  'moores': 13710,
#  'hometown': 10385,
#  'setback': 18695,
#  '12': 69,
#  'kirsten': 11841,
#  'chuck': 4265,
#  'crucial': 5441,
#  'details': 6176,
#  'flux': 8690,
#  'deadline': 5711,
#  'tillerson': 20983,
#  'ease': 7041,
#  'skepticism': 19142,
#  'reorganization': 17340,
#  'propose': 16352,
#  'pause': 15255,
#  'obamacare': 14478,
#  'kaspersky': 11720,
#  'lab': 11976,
#  'software': 19424,
#  'grassley': 9559,
#  'expresses': 7963,
#  'reservations': 17451,
#  'turn': 21541,
#  'evidence': 7674,
#  'michael': 13337,
#  'flynn': 8696,
#  'iran': 11292,
#  'decision': 5793,
#  'making': 12828,
#  'progress': 16266,
#  'nasty': 13996,
#  'believes': 2618,
#  'upbeat': 22009,
#  'study': 20120,
#  'hes': 10203,
#  'host': 10452,
#  'refiners': 17095,
#  'announce': 1517,
#  'adviser': 1026,
#  'policy': 15757,
#  'jobs': 11560,
#  'modest': 13616,
#  'impact': 10769,
#  'mostly': 13755,
#  'cuba': 5489,
#  'suspension': 20371,
#  'visas': 22382,
#  'hurting': 10596,
#  'families': 8168,
#  'embraces': 7267,
#  'message': 13300,
#  'eve': 7651,
#  'accusing': 888,
#  'extrump': 8033,
#  'communicating': 4707,
#  'media': 13178,
#  'must': 13913,
#  'nuclear': 14411,
#  'backer': 2224,
#  'inauguration': 10861,
#  'day': 5690,
#  'text': 20806,
#  'slammed': 19189,
#  'fake': 8136,
#  'math': 13072,
#  'adds': 957,
#  'cash': 3841,
#  'management': 12874,
#  'measures': 13162,
#  'due': 6934,
#  'debt': 5754,
#  'limit': 12423,
#  'accused': 884,
#  'inappropriate': 10855,
#  'conduct': 4842,
#  'nearly': 14066,
#  'half': 9845,
#  'americans': 1407,
#  'reutersipsos': 17619,
#  'reviewing': 17642,
#  'options': 14772,
#  'haley': 9843,
#  'accusers': 886,
#  'heard': 10095,
#  'even': 7653,
#  'target': 20584,
#  'contenders': 4993,
#  'emerge': 7272,
#  'no2': 14254,
#  'fed': 8309,
#  'search': 18494,
#  'narrow': 13983,
#  'powell': 15940,
#  'early': 7024,
#  'test': 20789,
#  'near': 14062,
#  'casts': 3862,
#  'referendum': 17087,
#  'pennsylvania': 15350,
#  'trial': 21327,
#  'goofy': 9445,
#  'gerrymandering': 9262,
#  'attends': 2056,
#  'civil': 4318,
#  'rights': 17736,
#  'museum': 13895,
#  'opening': 14720,
#  'black': 2831,
#  'stay': 19873,
#  'away': 2170,
#  'ukrainian': 21657,
#  'author': 2110,
#  'oped': 14712,
#  'sought': 19506,
#  'input': 11065,
#  'errors': 7527,
#  'filing': 8428,
#  'shows': 18954,
#  'drafted': 6817,
#  'ukraine': 21655,
#  'gag': 9105,
#  'order': 14787,
#  'admissions': 985,
#  'plummet': 15703,
#  'hanukkah': 9931,
#  'wells': 22734,
#  'fargo': 8202,
#  'lawyer': 12153,
#  'defending': 5872,
#  'grilled': 9625,
#  'reconsider': 16999,
#  'dina': 6334,
#  'resign': 17469,
#  'produces': 16231,
#  'takes': 20522,
#  'maryland': 13025,
#  'electoral': 7194,
#  'pressures': 16091,
#  'interviewed': 11209,
#  'franks': 8885,
#  'resigning': 17473,
#  'immediately': 10756,
#  'revamp': 17621,
#  'incomplete': 10892,
#  'social': 19401,
#  'conyers': 5077,
#  'held': 10154,
#  'nov': 14387,
#  'intensify': 11148,
#  'repatriation': 17352,
#  'cure': 5520,
#  'longterm': 12582,
#  'dollar': 6691,
#  'weakness': 22661,
#  'tries': 21345,
#  'refocus': 17104,
#  'remark': 17277,
#  'batter': 2493,
#  'rep': 17343,
#  'complaints': 4756,
#  'millions': 13436,
#  'lose': 12616,
#  'mortgage': 13744,
#  'gift': 9293,
#  'writeoffs': 23074,
#  'blackwater': 2857,
#  'founder': 8836,
#  'prince': 16138,
#  'russian': 18048,
#  'seychelles': 18740,
#  'averts': 2146,
#  'pioneer': 15580,
#  'eschew': 7543,
#  'attend': 2049,
#  'presiding': 16083,
#  'criminal': 5377,
#  'recused': 17031,
#  'probing': 16188,
#  'allegations': 1276,
#  'pearl': 15305,
#  'harbor': 9952,
#  'remembrance': 17285,
#  'intelligence': 11140,
#  'chairman': 4013,
#  'cleared': 4388,
#  'disclosing': 6420,
#  'classified': 4358,
#  'information': 11007,
#  'paul': 15249,
#  'tussle': 21556,
#  'passes': 15195,
#  'biofuel': 2785,
#  'manaforts': 12870,
#  'draft': 6815,
#  'violate': 22357,
#  'doesnt': 6678,
#  'foresee': 8770,
#  'libya': 12360,
#  'pushing': 16570,
#  'removed': 17300,
#  'list': 12464,
#  'pelosi': 15330,
#  'thursday': 20945,
#  'procurement': 16221,
#  'time': 20990,
#  'major': 12813,
#  'weapons': 22673,
#  'programs': 16265,
#  'wray': 23051,
#  'bureau': 3506,
#  'wake': 22504,
#  'criticism': 5397,
#  'presidents': 16081,
#  'legitimate': 12258,
#  'reasons': 16921,
#  'answer': 1538,
#  'enforcement': 7375,
#  'clears': 4393,
#  'hurdle': 10581,
#  'regulators': 17170,
#  'offer': 14594,
#  'olive': 14653,
#  'branch': 3210,
#  'loans': 12516,
#  'focused': 8703,
#  'getting': 9271,
#  'lowest': 12661,
#  'possible': 15866,
#  'arbitration': 1800,
#  'claims': 4330,
#  'feels': 8327,
#  'good': 9434,
#  'interior': 11177,
#  'oil': 14627,
#  'expedite': 7889,
#  'anwr': 1689,
#  'permits': 15404,
#  '1145': 53,
#  'announcement': 1519,
#  'sides': 19013,
#  'unions': 21860,
#  'high': 10228,
#  'fees': 8329,
#  'questioned': 16644,
#  ...}

# %%
# length
len(cv.vocabulary_)
# Out:
# 23279

# %%
## make this a numeric matrix 
num_news = cv.transform(news_data.title2)

# %%
num_news.shape
# Out:
# (44898, 23279)

# %%
news_data.shape
# Out:
# (44898, 10)

# %% [markdown]
# TfidfTransformer

# %%
tfidf = TfidfVectorizer(token_pattern="[\w']+", ngram_range=(1,2))
tfidf.fit(news_data.title2)
# Out:
# TfidfVectorizer(ngram_range=(1, 2), token_pattern="[\\w']+")

# %%
trans_tf = tfidf.transform(news_data.title2)

# %%
### too big to run in colab 
# tf_df= pd.DataFrame(trans_tf.toarray(), columns=tfidf.get_feature_names_out())
# tf_df.head(5)

# %%
# plot heatmap 
# plt.figure(figsize=(4,6))

# sns.heatmap(tf_df.T, xticklabels=True, yticklabels=True, cmap='Blues')
# plt.show()

# %%
import spacy
from spacy import cli

# %% [markdown]
# # Deep Learning/Tenserflow
